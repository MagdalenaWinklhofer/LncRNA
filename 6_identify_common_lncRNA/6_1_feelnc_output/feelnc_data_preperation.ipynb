# %%
#all needed packages 
import pandas as pd
import matplotlib as mpl
from itertools import product
import numpy as np

# %% [markdown]
# # Import data

# %%
#feelnc = pd.read_csv("feelnc_lncRNA_codpot_shuffle_RF.txt", sep="\t")
feelnc = pd.read_csv("all/feelnc_candidate_lncRNA_all.gtf_RF.txt", sep="\t")

# %%
feelnc
# Out:
#                name  kmerScore_1mer  kmerScore_2mer  kmerScore_3mer  \
# 0          STRG.1.1        0.500335        0.501229        0.539019
# 1         STRG.10.1        0.493775        0.488662        0.510004
# 2        STRG.100.1        0.498394        0.496114        0.478470
# 3      STRG.10001.1        0.496488        0.492918        0.471149
# 4      STRG.10002.1        0.503468        0.506440        0.494345
# ...             ...             ...             ...             ...
# 63638    STRG.999.1        0.499868        0.500416        0.501801
# 63639   STRG.9996.1        0.497581        0.493076        0.485885
# 63640   STRG.9997.1        0.499050        0.496316        0.487957
# 63641   STRG.9997.2        0.499050        0.496316        0.487957
# 63642   STRG.9997.3        0.499050        0.496316        0.487957
#
#        kmerScore_6mer  kmerScore_9mer  kmerScore_12mer  ORF_cover  RNA_size  \
# ...

# %% [markdown]
# A proportion close to 0 will indicate a non-coding RNA and close to 1 an mRNA.(Wucher et al. 2017)

# %%
# filter lncRNA_gffread for label 0 
feelnc = feelnc[feelnc["label"] == 0]

# %%
len(feelnc)
# Out:
# 53136

# %%
feelnc
# Out:
#                name  kmerScore_1mer  kmerScore_2mer  kmerScore_3mer  \
# 0          STRG.1.1        0.500335        0.501229        0.539019
# 1         STRG.10.1        0.493775        0.488662        0.510004
# 2        STRG.100.1        0.498394        0.496114        0.478470
# 3      STRG.10001.1        0.496488        0.492918        0.471149
# 4      STRG.10002.1        0.503468        0.506440        0.494345
# ...             ...             ...             ...             ...
# 63638    STRG.999.1        0.499868        0.500416        0.501801
# 63639   STRG.9996.1        0.497581        0.493076        0.485885
# 63640   STRG.9997.1        0.499050        0.496316        0.487957
# 63641   STRG.9997.2        0.499050        0.496316        0.487957
# 63642   STRG.9997.3        0.499050        0.496316        0.487957
#
#        kmerScore_6mer  kmerScore_9mer  kmerScore_12mer  ORF_cover  RNA_size  \
# ...

# %%
# convert all the characters in the "name" column in lower case
feelnc["name"] = feelnc["name"].str.lower()
# Out:
# /tmp/ipykernel_2238/1144009185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feelnc["name"] = feelnc["name"].str.lower()

# %%
# export the dataframe to a csv file
feelnc.to_csv('feelnc_lncRNA.csv', index=False)
