# %%
# Import of needed packages
import pandas as pd
from tabulate import tabulate
# run this Python code (in a Python interpreter) from a folder where all files are present
from bioinfokit.analys import HtsAna

# %%
# make sure all individual count files are present in same folder
# by default, it assumes each count file has .txt extension
HtsAna.merge_featureCount('*.txt', 'Geneid')

# %%
df = pd.read_csv("gene_matrix_count.csv", header=0,
                 sep=',', index_col='Geneid')
df
# Out:
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R12.bam  \
# Geneid
# MSTRG.1.1                                                                1099
# MSTRG.1.2                                                                1095
# MSTRG.2.1                                                                   2
# ccar_ua01-g3.t2                                                           154
# ccar_ua01-g3.t2.1.6676fed8                                                158
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       7
# scaffold_72-g45759.t1                                                      28
# scaffold_72-g45760.t1                                                      30
# scaffold_129-g45565.t1                                                     15
# scaffold_129-g45566.t1                                                      6
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A5.bam  \
# Geneid
# MSTRG.1.1                                                                1375
# MSTRG.1.2                                                                1374
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                            89
# ccar_ua01-g3.t2.1.6676fed8                                                 90
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       2
# scaffold_72-g45759.t1                                                      22
# scaffold_72-g45760.t1                                                      26
# scaffold_129-g45565.t1                                                      9
# scaffold_129-g45566.t1                                                      5
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A4.bam  \
# Geneid
# MSTRG.1.1                                                                1529
# MSTRG.1.2                                                                1524
# MSTRG.2.1                                                                   1
# ccar_ua01-g3.t2                                                           135
# ccar_ua01-g3.t2.1.6676fed8                                                136
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       2
# scaffold_72-g45759.t1                                                      29
# scaffold_72-g45760.t1                                                      31
# scaffold_129-g45565.t1                                                      2
# scaffold_129-g45566.t1                                                      1
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A6.bam  \
# Geneid
# MSTRG.1.1                                                                1332
# MSTRG.1.2                                                                1330
# MSTRG.2.1                                                                   1
# ccar_ua01-g3.t2                                                           113
# ccar_ua01-g3.t2.1.6676fed8                                                117
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       3
# scaffold_72-g45759.t1                                                      25
# scaffold_72-g45760.t1                                                      24
# scaffold_129-g45565.t1                                                      3
# scaffold_129-g45566.t1                                                      4
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N16.bam  \
# Geneid
# MSTRG.1.1                                                                1222
# MSTRG.1.2                                                                1218
# MSTRG.2.1                                                                   2
# ccar_ua01-g3.t2                                                           172
# ccar_ua01-g3.t2.1.6676fed8                                                173
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       9
# scaffold_72-g45759.t1                                                      13
# scaffold_72-g45760.t1                                                      17
# scaffold_129-g45565.t1                                                      5
# scaffold_129-g45566.t1                                                      6
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N15.bam  \
# Geneid
# MSTRG.1.1                                                                 967
# MSTRG.1.2                                                                 964
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                           160
# ccar_ua01-g3.t2.1.6676fed8                                                162
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       5
# scaffold_72-g45759.t1                                                      15
# scaffold_72-g45760.t1                                                      18
# scaffold_129-g45565.t1                                                      3
# scaffold_129-g45566.t1                                                      2
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R9.bam  \
# Geneid
# MSTRG.1.1                                                                1281
# MSTRG.1.2                                                                1277
# MSTRG.2.1                                                                   1
# ccar_ua01-g3.t2                                                           169
# ccar_ua01-g3.t2.1.6676fed8                                                172
# ...                                                                       ...
# scaffold_72-g45758.t1                                                      10
# scaffold_72-g45759.t1                                                      32
# scaffold_72-g45760.t1                                                      35
# scaffold_129-g45565.t1                                                      2
# scaffold_129-g45566.t1                                                      4
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A1.bam  \
# Geneid
# MSTRG.1.1                                                                1284
# MSTRG.1.2                                                                1284
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                           102
# ccar_ua01-g3.t2.1.6676fed8                                                102
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       5
# scaffold_72-g45759.t1                                                      22
# scaffold_72-g45760.t1                                                      21
# scaffold_129-g45565.t1                                                      5
# scaffold_129-g45566.t1                                                      7
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N14.bam  \
# Geneid
# MSTRG.1.1                                                                1087
# MSTRG.1.2                                                                1085
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                           137
# ccar_ua01-g3.t2.1.6676fed8                                                140
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       6
# scaffold_72-g45759.t1                                                      23
# scaffold_72-g45760.t1                                                      21
# scaffold_129-g45565.t1                                                      5
# scaffold_129-g45566.t1                                                      1
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R8.bam  \
# Geneid
# MSTRG.1.1                                                                1174
# MSTRG.1.2                                                                1173
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                           185
# ccar_ua01-g3.t2.1.6676fed8                                                190
# ...                                                                       ...
# scaffold_72-g45758.t1                                                      11
# scaffold_72-g45759.t1                                                      26
# scaffold_72-g45760.t1                                                      35
# scaffold_129-g45565.t1                                                      5
# scaffold_129-g45566.t1                                                      5
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A3.bam  \
# Geneid
# MSTRG.1.1                                                                1436
# MSTRG.1.2                                                                1433
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                            94
# ccar_ua01-g3.t2.1.6676fed8                                                 95
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       0
# scaffold_72-g45759.t1                                                      28
# scaffold_72-g45760.t1                                                      21
# scaffold_129-g45565.t1                                                      4
# scaffold_129-g45566.t1                                                      3
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A2.bam  \
# Geneid
# MSTRG.1.1                                                                1381
# MSTRG.1.2                                                                1379
# MSTRG.2.1                                                                   1
# ccar_ua01-g3.t2                                                           123
# ccar_ua01-g3.t2.1.6676fed8                                                124
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       6
# scaffold_72-g45759.t1                                                      23
# scaffold_72-g45760.t1                                                      34
# scaffold_129-g45565.t1                                                      0
# scaffold_129-g45566.t1                                                      1
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R13.bam  \
# Geneid
# MSTRG.1.1                                                                1068
# MSTRG.1.2                                                                1065
# MSTRG.2.1                                                                   2
# ccar_ua01-g3.t2                                                           189
# ccar_ua01-g3.t2.1.6676fed8                                                193
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       4
# scaffold_72-g45759.t1                                                      22
# scaffold_72-g45760.t1                                                      26
# scaffold_129-g45565.t1                                                     11
# scaffold_129-g45566.t1                                                      4
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R10.bam  \
# Geneid
# MSTRG.1.1                                                                1168
# MSTRG.1.2                                                                1165
# MSTRG.2.1                                                                   0
# ccar_ua01-g3.t2                                                           229
# ccar_ua01-g3.t2.1.6676fed8                                                236
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       7
# scaffold_72-g45759.t1                                                      32
# scaffold_72-g45760.t1                                                      28
# scaffold_129-g45565.t1                                                     10
# scaffold_129-g45566.t1                                                      8
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R11.bam  \
# Geneid
# MSTRG.1.1                                                                1081
# MSTRG.1.2                                                                1079
# MSTRG.2.1                                                                   2
# ccar_ua01-g3.t2                                                           187
# ccar_ua01-g3.t2.1.6676fed8                                                192
# ...                                                                       ...
# scaffold_72-g45758.t1                                                      11
# scaffold_72-g45759.t1                                                      34
# scaffold_72-g45760.t1                                                      35
# scaffold_129-g45565.t1                                                      6
# scaffold_129-g45566.t1                                                      7
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N18.bam  \
# Geneid
# MSTRG.1.1                                                                1117
# MSTRG.1.2                                                                1115
# MSTRG.2.1                                                                   1
# ccar_ua01-g3.t2                                                           189
# ccar_ua01-g3.t2.1.6676fed8                                                189
# ...                                                                       ...
# scaffold_72-g45758.t1                                                      16
# scaffold_72-g45759.t1                                                      21
# scaffold_72-g45760.t1                                                      17
# scaffold_129-g45565.t1                                                     11
# scaffold_129-g45566.t1                                                      3
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N21.bam  \
# Geneid
# MSTRG.1.1                                                                1057
# MSTRG.1.2                                                                1050
# MSTRG.2.1                                                                   2
# ccar_ua01-g3.t2                                                           176
# ccar_ua01-g3.t2.1.6676fed8                                                178
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       6
# scaffold_72-g45759.t1                                                      21
# scaffold_72-g45760.t1                                                      13
# scaffold_129-g45565.t1                                                     12
# scaffold_129-g45566.t1                                                      6
#
#                             /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N17.bam
# Geneid
# MSTRG.1.1                                                                 902
# MSTRG.1.2                                                                 899
# MSTRG.2.1                                                                   3
# ccar_ua01-g3.t2                                                           147
# ccar_ua01-g3.t2.1.6676fed8                                                151
# ...                                                                       ...
# scaffold_72-g45758.t1                                                       4
# scaffold_72-g45759.t1                                                      10
# scaffold_72-g45760.t1                                                       9
# scaffold_129-g45565.t1                                                      4
# scaffold_129-g45566.t1                                                      3
#
# [131948 rows x 18 columns]

# %%
# Define a function to extract the desired substring
def extract_sample_name(column_name):
    # Find the last occurrence of '/' and '.'
    last_slash = column_name.rfind('/')
    last_dot = column_name.rfind('.')

    # Extract the substring between the last '/' and the last '.'
    sample_name = column_name[last_slash + 1:last_dot]

    return sample_name

# Apply the function to each column and rename the columns
df.columns = df.columns.map(extract_sample_name)

# Display the resulting DataFrame with renamed columns
print(df)

# export the dataframe to a csv file
df.to_csv("gene_matrix_count.csv")
# Out:
#                              R12    A5    A4    A6   N16  N15    R9    A1  \
# Geneid
# MSTRG.1.1                   1099  1375  1529  1332  1222  967  1281  1284
# MSTRG.1.2                   1095  1374  1524  1330  1218  964  1277  1284
# MSTRG.2.1                      2     0     1     1     2    0     1     0
# ccar_ua01-g3.t2              154    89   135   113   172  160   169   102
# ccar_ua01-g3.t2.1.6676fed8   158    90   136   117   173  162   172   102
# ...                          ...   ...   ...   ...   ...  ...   ...   ...
# scaffold_72-g45758.t1          7     2     2     3     9    5    10     5
# scaffold_72-g45759.t1         28    22    29    25    13   15    32    22
# scaffold_72-g45760.t1         30    26    31    24    17   18    35    21
# scaffold_129-g45565.t1        15     9     2     3     5    3     2     5
# scaffold_129-g45566.t1         6     5     1     4     6    2     4     7
#
#                              N14    R8    A3    A2   R13   R10   R11   N18  \
# Geneid
# MSTRG.1.1                   1087  1174  1436  1381  1068  1168  1081  1117
# MSTRG.1.2                   1085  1173  1433  1379  1065  1165  1079  1115
# MSTRG.2.1                      0     0     0     1     2     0     2     1
# ccar_ua01-g3.t2              137   185    94   123   189   229   187   189
# ccar_ua01-g3.t2.1.6676fed8   140   190    95   124   193   236   192   189
# ...                          ...   ...   ...   ...   ...   ...   ...   ...
# scaffold_72-g45758.t1          6    11     0     6     4     7    11    16
# scaffold_72-g45759.t1         23    26    28    23    22    32    34    21
# scaffold_72-g45760.t1         21    35    21    34    26    28    35    17
# scaffold_129-g45565.t1         5     5     4     0    11    10     6    11
# scaffold_129-g45566.t1         1     5     3     1     4     8     7     3
#
#                              N21  N17
# Geneid
# MSTRG.1.1                   1057  902
# MSTRG.1.2                   1050  899
# MSTRG.2.1                      2    3
# ccar_ua01-g3.t2              176  147
# ccar_ua01-g3.t2.1.6676fed8   178  151
# ...                          ...  ...
# scaffold_72-g45758.t1          6    4
# scaffold_72-g45759.t1         21   10
# scaffold_72-g45760.t1         13    9
# scaffold_129-g45565.t1        12    4
# scaffold_129-g45566.t1         6    3
#
# [131948 rows x 18 columns]

# %% [markdown]
# # Create table to sample information

# %%
import pandas as pd

# Extract conditions from column names
conditions = []
for column in df.columns:
    if 'R' in column:
        conditions.append('reoxygenation')
    elif 'A' in column:
        conditions.append('anoxia')
    elif 'N' in column:
        conditions.append('normoxia')
    else:
        conditions.append('unknown')  # or handle other cases

# Create a new DataFrame
sample_info = pd.DataFrame({'Geneid': df.columns, 'condition': conditions[:len(df.columns)]})

# Display the resulting DataFrame
print(sample_info)

# export to csv
sample_info.to_csv('sample_info.csv', index=False)
# Out:
#    Geneid      condition
# 0     R12  reoxygenation
# 1      A5         anoxia
# 2      A4         anoxia
# 3      A6         anoxia
# 4     N16       normoxia
# 5     N15       normoxia
# 6      R9  reoxygenation
# 7      A1         anoxia
# 8     N14       normoxia
# 9      R8  reoxygenation
# 10     A3         anoxia
# 11     A2         anoxia
# 12    R13  reoxygenation
# 13    R10  reoxygenation
# 14    R11  reoxygenation
# 15    N18       normoxia
# 16    N21       normoxia
# 17    N17       normoxia
