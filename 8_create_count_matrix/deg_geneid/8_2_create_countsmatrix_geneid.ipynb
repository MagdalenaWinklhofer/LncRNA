# %%
# Import of needed packages
import pandas as pd
from tabulate import tabulate
# run this Python code (in a Python interpreter) from a folder where all files are present
from bioinfokit.analys import HtsAna

# %%
# make sure all individual count files are present in same folder
# by default, it assumes each count file has .txt extension
HtsAna.merge_featureCount('*.txt', 'Geneid')

# %%
df = pd.read_csv("gene_matrix_count.csv", header=0,
                 sep=',', index_col='Geneid')
df
# Out:
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R12.bam  \
# Geneid
# MSTRG.1                                                           1065
# MSTRG.2                                                              2
# MSTRG.3                                                            156
# MSTRG.4                                                            106
# MSTRG.5                                                            235
# ...                                                                ...
# scaffold_72-g45758                                                   7
# scaffold_72-g45759                                                  23
# scaffold_72-g45760                                                  26
# scaffold_129-g45565                                                 15
# scaffold_129-g45566                                                  6
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A5.bam  \
# Geneid
# MSTRG.1                                                           1345
# MSTRG.2                                                              0
# MSTRG.3                                                             85
# MSTRG.4                                                             52
# MSTRG.5                                                            153
# ...                                                                ...
# scaffold_72-g45758                                                   2
# scaffold_72-g45759                                                  21
# scaffold_72-g45760                                                  24
# scaffold_129-g45565                                                  9
# scaffold_129-g45566                                                  5
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A4.bam  \
# Geneid
# MSTRG.1                                                           1479
# MSTRG.2                                                              1
# MSTRG.3                                                            129
# MSTRG.4                                                            117
# MSTRG.5                                                            190
# ...                                                                ...
# scaffold_72-g45758                                                   2
# scaffold_72-g45759                                                  25
# scaffold_72-g45760                                                  26
# scaffold_129-g45565                                                  2
# scaffold_129-g45566                                                  1
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A6.bam  \
# Geneid
# MSTRG.1                                                           1303
# MSTRG.2                                                              1
# MSTRG.3                                                            114
# MSTRG.4                                                             93
# MSTRG.5                                                            188
# ...                                                                ...
# scaffold_72-g45758                                                   3
# scaffold_72-g45759                                                  22
# scaffold_72-g45760                                                  21
# scaffold_129-g45565                                                  2
# scaffold_129-g45566                                                  3
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N16.bam  \
# Geneid
# MSTRG.1                                                           1189
# MSTRG.2                                                              2
# MSTRG.3                                                            166
# MSTRG.4                                                            101
# MSTRG.5                                                            305
# ...                                                                ...
# scaffold_72-g45758                                                   9
# scaffold_72-g45759                                                  12
# scaffold_72-g45760                                                  16
# scaffold_129-g45565                                                  4
# scaffold_129-g45566                                                  4
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N15.bam  \
# Geneid
# MSTRG.1                                                            943
# MSTRG.2                                                              0
# MSTRG.3                                                            158
# MSTRG.4                                                            120
# MSTRG.5                                                            338
# ...                                                                ...
# scaffold_72-g45758                                                   5
# scaffold_72-g45759                                                  14
# scaffold_72-g45760                                                  17
# scaffold_129-g45565                                                  3
# scaffold_129-g45566                                                  2
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R9.bam  \
# Geneid
# MSTRG.1                                                           1251
# MSTRG.2                                                              1
# MSTRG.3                                                            170
# MSTRG.4                                                            118
# MSTRG.5                                                            266
# ...                                                                ...
# scaffold_72-g45758                                                  10
# scaffold_72-g45759                                                  29
# scaffold_72-g45760                                                  31
# scaffold_129-g45565                                                  2
# scaffold_129-g45566                                                  4
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A1.bam  \
# Geneid
# MSTRG.1                                                           1244
# MSTRG.2                                                              0
# MSTRG.3                                                            100
# MSTRG.4                                                             90
# MSTRG.5                                                            165
# ...                                                                ...
# scaffold_72-g45758                                                   5
# scaffold_72-g45759                                                  22
# scaffold_72-g45760                                                  21
# scaffold_129-g45565                                                  3
# scaffold_129-g45566                                                  5
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N14.bam  \
# Geneid
# MSTRG.1                                                           1075
# MSTRG.2                                                              0
# MSTRG.3                                                            137
# MSTRG.4                                                             85
# MSTRG.5                                                            339
# ...                                                                ...
# scaffold_72-g45758                                                   6
# scaffold_72-g45759                                                  21
# scaffold_72-g45760                                                  19
# scaffold_129-g45565                                                  5
# scaffold_129-g45566                                                  1
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R8.bam  \
# Geneid
# MSTRG.1                                                           1144
# MSTRG.2                                                              0
# MSTRG.3                                                            189
# MSTRG.4                                                            160
# MSTRG.5                                                            289
# ...                                                                ...
# scaffold_72-g45758                                                  11
# scaffold_72-g45759                                                  23
# scaffold_72-g45760                                                  32
# scaffold_129-g45565                                                  5
# scaffold_129-g45566                                                  5
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A3.bam  \
# Geneid
# MSTRG.1                                                           1407
# MSTRG.2                                                              0
# MSTRG.3                                                             91
# MSTRG.4                                                             91
# MSTRG.5                                                            152
# ...                                                                ...
# scaffold_72-g45758                                                   0
# scaffold_72-g45759                                                  28
# scaffold_72-g45760                                                  21
# scaffold_129-g45565                                                  4
# scaffold_129-g45566                                                  3
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/A2.bam  \
# Geneid
# MSTRG.1                                                           1349
# MSTRG.2                                                              1
# MSTRG.3                                                            119
# MSTRG.4                                                            106
# MSTRG.5                                                            195
# ...                                                                ...
# scaffold_72-g45758                                                   6
# scaffold_72-g45759                                                  20
# scaffold_72-g45760                                                  31
# scaffold_129-g45565                                                  0
# scaffold_129-g45566                                                  1
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R13.bam  \
# Geneid
# MSTRG.1                                                           1036
# MSTRG.2                                                              2
# MSTRG.3                                                            189
# MSTRG.4                                                            119
# MSTRG.5                                                            233
# ...                                                                ...
# scaffold_72-g45758                                                   4
# scaffold_72-g45759                                                  18
# scaffold_72-g45760                                                  23
# scaffold_129-g45565                                                 10
# scaffold_129-g45566                                                  3
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R10.bam  \
# Geneid
# MSTRG.1                                                           1137
# MSTRG.2                                                              0
# MSTRG.3                                                            227
# MSTRG.4                                                            133
# MSTRG.5                                                            252
# ...                                                                ...
# scaffold_72-g45758                                                   7
# scaffold_72-g45759                                                  31
# scaffold_72-g45760                                                  27
# scaffold_129-g45565                                                 10
# scaffold_129-g45566                                                  8
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/R11.bam  \
# Geneid
# MSTRG.1                                                           1056
# MSTRG.2                                                              2
# MSTRG.3                                                            188
# MSTRG.4                                                            125
# MSTRG.5                                                            275
# ...                                                                ...
# scaffold_72-g45758                                                  11
# scaffold_72-g45759                                                  32
# scaffold_72-g45760                                                  33
# scaffold_129-g45565                                                  3
# scaffold_129-g45566                                                  4
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N18.bam  \
# Geneid
# MSTRG.1                                                           1089
# MSTRG.2                                                              1
# MSTRG.3                                                            183
# MSTRG.4                                                            174
# MSTRG.5                                                            328
# ...                                                                ...
# scaffold_72-g45758                                                  16
# scaffold_72-g45759                                                  19
# scaffold_72-g45760                                                  15
# scaffold_129-g45565                                                 10
# scaffold_129-g45566                                                  2
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N21.bam  \
# Geneid
# MSTRG.1                                                           1029
# MSTRG.2                                                              2
# MSTRG.3                                                            173
# MSTRG.4                                                             70
# MSTRG.5                                                            350
# ...                                                                ...
# scaffold_72-g45758                                                   6
# scaffold_72-g45759                                                  20
# scaffold_72-g45760                                                  12
# scaffold_129-g45565                                                 11
# scaffold_129-g45566                                                  5
#
#                      /cluster/work/users/magdalena/lncrna/2_hisat_alignment/N17.bam
# Geneid
# MSTRG.1                                                            888
# MSTRG.2                                                              3
# MSTRG.3                                                            148
# MSTRG.4                                                             86
# MSTRG.5                                                            299
# ...                                                                ...
# scaffold_72-g45758                                                   4
# scaffold_72-g45759                                                   9
# scaffold_72-g45760                                                   8
# scaffold_129-g45565                                                  3
# scaffold_129-g45566                                                  2
#
# [47268 rows x 18 columns]

# %%
# Define a function to extract the desired substring
def extract_sample_name(column_name):
    # Find the last occurrence of '/' and '.'
    last_slash = column_name.rfind('/')
    last_dot = column_name.rfind('.')

    # Extract the substring between the last '/' and the last '.'
    sample_name = column_name[last_slash + 1:last_dot]

    return sample_name

# Apply the function to each column and rename the columns
df.columns = df.columns.map(extract_sample_name)

# Display the resulting DataFrame with renamed columns
print(df)

# export the dataframe to a csv file
df.to_csv("gene_matrix_count.csv")
# Out:
#                       R12    A5    A4    A6   N16  N15    R9    A1   N14  \
# Geneid
# MSTRG.1              1065  1345  1479  1303  1189  943  1251  1244  1075
# MSTRG.2                 2     0     1     1     2    0     1     0     0
# MSTRG.3               156    85   129   114   166  158   170   100   137
# MSTRG.4               106    52   117    93   101  120   118    90    85
# MSTRG.5               235   153   190   188   305  338   266   165   339
# ...                   ...   ...   ...   ...   ...  ...   ...   ...   ...
# scaffold_72-g45758      7     2     2     3     9    5    10     5     6
# scaffold_72-g45759     23    21    25    22    12   14    29    22    21
# scaffold_72-g45760     26    24    26    21    16   17    31    21    19
# scaffold_129-g45565    15     9     2     2     4    3     2     3     5
# scaffold_129-g45566     6     5     1     3     4    2     4     5     1
#
#                        R8    A3    A2   R13   R10   R11   N18   N21  N17
# Geneid
# MSTRG.1              1144  1407  1349  1036  1137  1056  1089  1029  888
# MSTRG.2                 0     0     1     2     0     2     1     2    3
# MSTRG.3               189    91   119   189   227   188   183   173  148
# MSTRG.4               160    91   106   119   133   125   174    70   86
# MSTRG.5               289   152   195   233   252   275   328   350  299
# ...                   ...   ...   ...   ...   ...   ...   ...   ...  ...
# scaffold_72-g45758     11     0     6     4     7    11    16     6    4
# scaffold_72-g45759     23    28    20    18    31    32    19    20    9
# scaffold_72-g45760     32    21    31    23    27    33    15    12    8
# scaffold_129-g45565     5     4     0    10    10     3    10    11    3
# scaffold_129-g45566     5     3     1     3     8     4     2     5    2
#
# [47268 rows x 18 columns]

# %% [markdown]
# # Create table to sample information

# %%
import pandas as pd

# Extract conditions from column names
conditions = []
for column in df.columns:
    if 'R' in column:
        conditions.append('reoxygenation')
    elif 'A' in column:
        conditions.append('anoxia')
    elif 'N' in column:
        conditions.append('normoxia')
    else:
        conditions.append('unknown')  # or handle other cases

# Create a new DataFrame
sample_info = pd.DataFrame({'Geneid': df.columns, 'condition': conditions[:len(df.columns)]})

# Display the resulting DataFrame
print(sample_info)

# export to csv
sample_info.to_csv('sample_info.csv', index=False)
# Out:
#    Geneid      condition
# 0     R12  reoxygenation
# 1      A5         anoxia
# 2      A4         anoxia
# 3      A6         anoxia
# 4     N16       normoxia
# 5     N15       normoxia
# 6      R9  reoxygenation
# 7      A1         anoxia
# 8     N14       normoxia
# 9      R8  reoxygenation
# 10     A3         anoxia
# 11     A2         anoxia
# 12    R13  reoxygenation
# 13    R10  reoxygenation
# 14    R11  reoxygenation
# 15    N18       normoxia
# 16    N21       normoxia
# 17    N17       normoxia
