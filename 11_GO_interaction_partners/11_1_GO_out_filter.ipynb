# %%
# Import packages 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import statsmodels.stats.multitest as smm
from pathlib import Path
from matplotlib.ticker import FixedFormatter, FixedLocator

# %%
go = pd.read_csv('11_functional_annotation/gene_id_degip_GOterms.csv')

# %%
go.loc[go['over_represented_pvalue'] < 0.05]
# Out:
#        category  over_represented_pvalue  under_represented_pvalue  \
# 1    GO:0000978             8.653477e-09                  1.000000
# 2    GO:0000122             7.798900e-07                  1.000000
# 3    GO:0000981             9.807147e-06                  0.999995
# 4    GO:0004879             2.636758e-05                  0.999996
# 5    GO:0005634             1.705584e-04                  0.999881
# ..          ...                      ...                       ...
# 409  GO:0048753             4.944711e-02                  0.999065
# 410  GO:0097048             4.944711e-02                  0.999065
# 411  GO:0031860             4.961560e-02                  0.999059
# 412  GO:0030942             4.965945e-02                  0.999057
# 413  GO:0090537             4.981751e-02                  0.999051
#
#      numDEInCat  numInCat                                               term  \
# 1            58      2038  RNA polymerase II cis-regulatory region sequen...
# ...

# %%
# calculate expected number in each category 
go['expectedDEInCat'] = (go['numInCat'])/45667*567
# calculate fold enrichment
go['foldEnrichment'] = (go['numDEInCat']/go['expectedDEInCat'])
# calculate padj value (to correct for multiple testing) 
go['padj'] = smm.multipletests(go['over_represented_pvalue'], method='bonferroni')[1]
go = go.sort_values(by='over_represented_pvalue')
go = go[go['over_represented_pvalue'] <= 0.05]

# %%
go
# Out:
#        category  over_represented_pvalue  under_represented_pvalue  \
# 1    GO:0000978             8.653477e-09                  1.000000
# 2    GO:0000122             7.798900e-07                  1.000000
# 3    GO:0000981             9.807147e-06                  0.999995
# 4    GO:0004879             2.636758e-05                  0.999996
# 5    GO:0005634             1.705584e-04                  0.999881
# ..          ...                      ...                       ...
# 407  GO:0016248             4.944711e-02                  0.999065
# 404  GO:0002326             4.944711e-02                  0.999065
# 411  GO:0031860             4.961560e-02                  0.999059
# 412  GO:0030942             4.965945e-02                  0.999057
# 413  GO:0090537             4.981751e-02                  0.999051
#
#      numDEInCat  numInCat                                               term  \
# 1            58      2038  RNA polymerase II cis-regulatory region sequen...
# ...

# %%
go_selection = go.loc[go['padj'] <= 0.05]

# %%
go_selection
# Out:
#      category  over_represented_pvalue  under_represented_pvalue  numDEInCat  \
# 1  GO:0000978             8.653477e-09                       1.0          58
# 2  GO:0000122             7.798900e-07                       1.0          43
#
#    numInCat                                               term ontology  \
# 1      2038  RNA polymerase II cis-regulatory region sequen...       MF
# 2      1453  negative regulation of transcription by RNA po...       BP
#
#    expectedDEInCat  foldEnrichment      padj
# 1        25.303742        2.292151  0.000152
# 2        18.040401        2.383539  0.013664
