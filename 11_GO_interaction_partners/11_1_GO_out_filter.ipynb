# %%
# Import packages 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import statsmodels.stats.multitest as smm
from pathlib import Path
from matplotlib.ticker import FixedFormatter, FixedLocator

# %% [markdown]
# # 1 Import Data

# %%
# Import DEG data 
# Define the file paths
file_paths = {
    'na_up': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_normoxia_to_anoxia_up.csv',
    'na_down': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_normoxia_to_anoxia_down.csv',
    'nr_up': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_normoxia_to_reoxygenation_up.csv',
    'nr_down': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_normoxia_to_reoxygenation_down.csv',
    'ar_up': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_anoxia_to_reoxygenation_up.csv',
    'ar_down': '../9_1_dea_lncrna/9_1_2_deg_geneid/deg_data/deg_anoxia_to_reoxygenation_down.csv'
}

# Read the data files
dfs = {key: pd.read_csv(path) for key, path in file_paths.items()}

# Concatenate DataFrames into a new dictionary
deg = {
    'deg_na': pd.concat([dfs['na_up'], dfs['na_down']]),
    'deg_nr': pd.concat([dfs['nr_up'], dfs['nr_down']]),
    'deg_ar': pd.concat([dfs['ar_up'], dfs['ar_down']])
}

# Import GO data 
# Geneid to GO term
goterm = pd.read_csv('ccar2swissprotGO_long.txt', sep='\t') 
# rename columns
goterm.columns = ['gene_id', 'id']
# GO term to description
godesc = pd.read_csv('go_data.txt', sep='\t')
godesc.set_index('id', inplace=True)

# %%
pd.concat([dfs['na_up'], dfs['na_down']])
# Out:
#                  gene_id    baseMean  log2FoldChange     lfcSE       stat  \
# 0                 strg.7    8.583446        1.668757  0.377595   3.417007
# 1                strg.16  118.239224        1.568549  0.245600   4.845425
# 2                strg.18  144.498891        0.945254  0.197304   2.872428
# 3                strg.22   15.908223        1.697089  0.358630   3.676703
# 4                strg.36  182.533076        1.643123  0.122581  10.316574
# ...                  ...         ...             ...       ...        ...
# 5919    ccar_ub25-g45078   40.030600       -0.978585  0.216295  -2.774327
# 5920    ccar_ub25-g45127  133.654316       -1.378683  0.102964  -9.713824
# 5921    ccar_ub25-g45350    7.695890       -1.573564  0.436254  -2.739352
# 5922    ccar_ub25-g45355   46.443179       -1.318460  0.209459  -4.487507
# 5923  scaffold_45-g45721   19.121963       -2.364288  0.416401  -4.768899
#
#             pvalue          padj regulation           condition    -log10p  \
# 0     6.331374e-04  2.788787e-03         up  Normoxia to Anoxia   2.554585
# 1     1.263410e-06  7.623835e-06         up  Normoxia to Anoxia   5.117827
# 2     4.073305e-03  1.588934e-02         up  Normoxia to Anoxia   1.798894
# 3     2.362677e-04  1.100085e-03         up  Normoxia to Anoxia   2.958574
# 4     5.930179e-25  1.143458e-23         up  Normoxia to Anoxia  22.941780
# ...            ...           ...        ...                 ...        ...
# 5919  5.531604e-03  2.103304e-02         up  Normoxia to Anoxia   1.677098
# 5920  2.632712e-22  4.446298e-21         up  Normoxia to Anoxia  20.352001
# 5921  6.156047e-03  2.320914e-02         up  Normoxia to Anoxia   1.634341
# 5922  7.206132e-06  4.014789e-05         up  Normoxia to Anoxia   4.396337
# 5923  1.852358e-06  1.098036e-05         up  Normoxia to Anoxia   4.959383
#
#                                 color
# 0            Differentially Expressed
# 1            Differentially Expressed
# 2            Differentially Expressed
# 3     Differentially Expressed LncRNA
# 4            Differentially Expressed
# ...                               ...
# 5919         Differentially Expressed
# 5920         Differentially Expressed
# 5921         Differentially Expressed
# 5922         Differentially Expressed
# 5923         Differentially Expressed
#
# [11617 rows x 11 columns]

# %% [markdown]
# # Match GO term to gene_id before GO enrichment analysis

# %% [markdown]
# # 3 GO analysis output

# %%
partner = pd.read_csv('../10_lncRNA_classification/GO_analysis_input/lncRNA_deg_geneid.csv')

# %%
interaction = pd.read_csv('11_functional_annotation/lncRNA_deg_geneid_GOterms_test.csv')

# total number of genes in the background dataset 
total_num_genes = pd.read_csv('../A_annotation/carcar_annotation_v5_gene_lengths.csv', sep=',')

# %%
interaction
# Out:
#           category  over_represented_pvalue  under_represented_pvalue  \
# 1       GO:0099645                 0.000061                  0.999992
# 2       GO:0007156                 0.000295                  0.999892
# 3       GO:0051930                 0.000401                  0.999964
# 4       GO:0003964                 0.000413                  0.999870
# 5       GO:0016339                 0.000535                  0.999888
# ...            ...                      ...                       ...
# 19121   GO:0090132                 1.000000                  0.980289
# 19122   GO:0070861                 1.000000                  0.979817
# 19123   GO:0071955                 1.000000                  0.979817
# 19124   GO:0097069                 1.000000                  0.935484
# 19125   GO:0034398                 1.000000                  0.940022
#
#        numDEInCat  numInCat term ontology
# 1               8        68  NaN      NaN
# 2              20       393  NaN      NaN
# 3               5        32  NaN      NaN
# 4              15       273  NaN      NaN
# 5               9       111  NaN      NaN
# ...           ...       ...  ...      ...
# 19121           0         1  NaN      NaN
# 19122           0         1  NaN      NaN
# 19123           0         1  NaN      NaN
# 19124           0         3  NaN      NaN
# 19125           0         3  NaN      NaN
#
# [19125 rows x 7 columns]

# %%
interaction['category'] = interaction['category'].str.strip()

# %%
interaction['term'] = godesc.loc[interaction['category']]['name'].to_numpy()

# %%
interaction['ontology'] = godesc.loc[interaction['category']]['namespace'].to_numpy()

# %%
interaction['expectedDEInCat'] = (interaction['numInCat']/len(total_num_genes))*len(partner)

# %%
interaction['foldEnrichment'] = interaction['numDEInCat']/interaction['expectedDEInCat']

# %%
interaction
# Out:
#          category  over_represented_pvalue  under_represented_pvalue  \
# 1      GO:0099645                 0.000061                  0.999992
# 2      GO:0007156                 0.000295                  0.999892
# 3      GO:0051930                 0.000401                  0.999964
# 4      GO:0003964                 0.000413                  0.999870
# 5      GO:0016339                 0.000535                  0.999888
# ...           ...                      ...                       ...
# 19121  GO:0090132                 1.000000                  0.980289
# 19122  GO:0070861                 1.000000                  0.979817
# 19123  GO:0071955                 1.000000                  0.979817
# 19124  GO:0097069                 1.000000                  0.935484
# 19125  GO:0034398                 1.000000                  0.940022
#
#        numDEInCat  numInCat  \
# 1               8        68
# 2              20       393
# 3               5        32
# 4              15       273
# 5               9       111
# ...           ...       ...
# 19121           0         1
# 19122           0         1
# 19123           0         1
# 19124           0         3
# 19125           0         3
#
#                                                     term ontology  \
# 1      neurotransmitter receptor localization to post...       BP
# 2      homophilic cell adhesion via plasma membrane a...       BP
# 3               regulation of sensory perception of pain       BP
# 4                   RNA-directed DNA polymerase activity       MF
# 5      calcium-dependent cell-cell adhesion via plasm...       BP
# ...                                                  ...      ...
# 19121                               epithelium migration       BP
# 19122  regulation of protein exit from endoplasmic re...       BP
# 19123              recycling endosome to Golgi transport       BP
# 19124            cellular response to thyroxine stimulus       BP
# 19125            telomere tethering at nuclear periphery       BP
#
#        expectedDEInCat  foldEnrichment
# 1             1.596251        5.011743
# 2             9.225393        2.167929
# 3             0.751177        6.656221
# 4             6.408479        2.340649
# 5             2.605645        3.454039
# ...                ...             ...
# 19121         0.023474        0.000000
# 19122         0.023474        0.000000
# 19123         0.023474        0.000000
# 19124         0.070423        0.000000
# 19125         0.070423        0.000000
#
# [19125 rows x 9 columns]

# %%
interaction['padj'] = smm.multipletests(interaction['over_represented_pvalue'],method='bonferroni')[1]

# %%
interaction['-log10(padj)'] = -np.log10(interaction['padj'])

# %%
interaction = interaction.sort_values(by='padj')

# %%
interaction.head(15)
# Out:
#          category  over_represented_pvalue  under_represented_pvalue  \
# 1      GO:0099645                 0.000061                  0.999992
# 12753  GO:0090175                 1.000000                  0.835983
# 12752  GO:0090170                 1.000000                  0.852789
# 12751  GO:0090168                 1.000000                  0.795717
# 12750  GO:0090158                 1.000000                  0.850245
# 12749  GO:0090156                 1.000000                  0.751427
# 12748  GO:0090150                 1.000000                  0.830220
# 12754  GO:0090176                 1.000000                  0.835626
# 12747  GO:0090141                 1.000000                  0.450071
# 12745  GO:0090131                 1.000000                  0.887428
# 12744  GO:0090119                 1.000000                  0.786874
# 12743  GO:0090118                 1.000000                  0.852564
# 12742  GO:0090110                 1.000000                  0.419943
# 12741  GO:0090108                 1.000000                  0.870509
# 12740  GO:0090107                 1.000000                  0.872630
#
#        numDEInCat  numInCat  \
# 1               8        68
# 12753           0         9
# 12752           0         8
# 12751           0        11
# 12750           0         8
# 12749           0        14
# 12748           0         9
# 12754           0         9
# 12747           0        40
# 12745           0         6
# 12744           0        12
# 12743           0         8
# 12742           0        43
# 12741           0         6
# 12740           0         6
#
#                                                     term ontology  \
# 1      neurotransmitter receptor localization to post...       BP
# 12753     regulation of establishment of planar polarity       BP
# 12752                    regulation of Golgi inheritance       BP
# 12751                                   Golgi reassembly       BP
# 12750        endoplasmic reticulum membrane organization       BP
# 12749             intracellular sphingolipid homeostasis       BP
# 12748  establishment of protein localization to membrane       BP
# 12754  microtubule cytoskeleton organization involved...       BP
# 12747       positive regulation of mitochondrial fission       BP
# 12745                               mesenchyme migration       BP
# 12744             vesicle-mediated cholesterol transport       BP
# 12743  receptor-mediated endocytosis involved in chol...       BP
# 12742                 COPII-coated vesicle cargo loading       BP
# 12741  positive regulation of high-density lipoprotei...       BP
# 12740  regulation of high-density lipoprotein particl...       BP
#
#        expectedDEInCat  foldEnrichment  padj  -log10(padj)
# 1             1.596251        5.011743   1.0          -0.0
# 12753         0.211269        0.000000   1.0          -0.0
# 12752         0.187794        0.000000   1.0          -0.0
# 12751         0.258217        0.000000   1.0          -0.0
# 12750         0.187794        0.000000   1.0          -0.0
# 12749         0.328640        0.000000   1.0          -0.0
# 12748         0.211269        0.000000   1.0          -0.0
# 12754         0.211269        0.000000   1.0          -0.0
# 12747         0.938971        0.000000   1.0          -0.0
# 12745         0.140846        0.000000   1.0          -0.0
# 12744         0.281691        0.000000   1.0          -0.0
# 12743         0.187794        0.000000   1.0          -0.0
# 12742         1.009394        0.000000   1.0          -0.0
# 12741         0.140846        0.000000   1.0          -0.0
# 12740         0.140846        0.000000   1.0          -0.0

# %%
interaction = interaction[interaction['padj'] <= 0.05]

# %%
interaction
# Out:
# Empty DataFrame
# Columns: [category, over_represented_pvalue, under_represented_pvalue, numDEInCat, numInCat, term, ontology, expectedDEInCat, foldEnrichment, padj, -log10(padj)]
# Index: []
